# %%
import psycopg2
import pandas as pd

# %%
from secret import PASSWORD, USER, HOST, PORT

# %%
# Database name
database = "postgres"

# Construct the connection string
conn_string = f"host={HOST} dbname={database} user={USER} password={PASSWORD} port={PORT}"

# %%
# Establish the connection and load data into a DataFrame
try:
    conn = psycopg2.connect(conn_string)
    print("Connected to the database successfully!")

    # Create a cursor object to execute SQL queries
    cur = conn.cursor()

    # Execute your SQL query
    cur.execute("SELECT * FROM public.menu")

    # Fetch all rows from the executed query
    rows = cur.fetchall()

    # Get column names from the cursor description
    columns = [desc[0] for desc in cur.description]

    # Create a DataFrame from the fetched data
    df_menu = pd.DataFrame(rows, columns=columns)

    # Print the DataFrame
    print(df_menu)

    # Close the cursor and connection
    cur.close()
    conn.close()
    print("Database connection closed.")

except (Exception, psycopg2.Error) as error:
    print("Error while connecting to PostgreSQL:", error)
# Out:
# Connected to the database successfully!
#      id photo studentprice guestprice pupilprice  \
# 0   493   N/A         5,60       5,60       5,60
# 1   689   N/A         5,20       5,20       5,20
# 2   247   N/A         2,85       6,60       6,60
# 3   250   N/A         4,50       8,90       8,90
# 4   251   N/A         4,20       8,50       8,50
# 5   252   N/A         3,90       8,20       8,20
# 6   246   N/A         1,10       1,50       1,50
# 7   248   N/A         1,05       1,65       1,65
# 8   249   N/A         1,05       1,65       1,65
# 9   519   N/A         3,45       7,10       7,10
# 10  523   N/A         3,45       7,10       7,10
# 11  529   N/A         3,45       7,10       7,10
# 12  535   N/A         3,45       7,10       7,10
# 13  533   N/A            -          -          -
# 14  532   N/A            -          -          -
# 15  530   N/A         1,10       1,50       1,50
# 16  534   N/A         1,05       1,65       1,65
# ...

# %%
# Establish the connection and load data into a DataFrame
try:
    conn = psycopg2.connect(conn_string)
    print("Connected to the database successfully!")

    # Create a cursor object to execute SQL queries
    cur = conn.cursor()

    # Execute your SQL query to fetch unique IDs
    cur.execute("SELECT DISTINCT id FROM public.menu")

    # Fetch all unique IDs from the executed query
    unique_ids = cur.fetchall()

    # Print the unique IDs
    print("Unique IDs in the menu table:")
    for uid in unique_ids:
        print(uid[0])

    # Close the cursor and connection
    cur.close()
    conn.close()
    print("Database connection closed.")

except (Exception, psycopg2.Error) as error:
    print("Error while connecting to PostgreSQL:", error)
# Out:
# Connected to the database successfully!
# Unique IDs in the menu table:
# 529
# 612
# 623
# 532
# 249
# 622
# 616
# 250
# 247
# 523
# 624
# 626
# 519
# 530
# 252
# 493
# 248
# 246
# 534
# 251
# 627
# 533
# 625
# 531
# 535
# 689
# 620
# Database connection closed.
