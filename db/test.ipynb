# %%
import psycopg2
import pandas as pd

# %%
from secret import PASSWORD, USER, HOST, PORT

# %%
# Database name
database = "postgres"

# Construct the connection string
conn_string = f"host={HOST} dbname={database} user={USER} password={PASSWORD} port={PORT}"

# Establish the connection and load data into a DataFrame
try:
    conn = psycopg2.connect(conn_string)
    print("Connected to the database successfully!")

    # Create a cursor object to execute SQL queries
    cur = conn.cursor()

    # Execute your SQL query
    cur.execute("SELECT * FROM public.menu")

    # Fetch all rows from the executed query
    rows = cur.fetchall()

    # Get column names from the cursor description
    columns = [desc[0] for desc in cur.description]

    # Create a DataFrame from the fetched data
    df_menu = pd.DataFrame(rows, columns=columns)

    # Print the DataFrame
    print(df_menu)

    # Close the cursor and connection
    cur.close()
    conn.close()
    print("Database connection closed.")

except (Exception, psycopg2.Error) as error:
    print("Error while connecting to PostgreSQL:", error)
# Out:
# Connected to the database successfully!
#      id               menuline                                 photo  \
# 0  None       Offer of the day  1133e83402e4e6d59072badb832e52b3.png
# 1  None       Offer of the day                                   N/A
# 2  None  Offer D. Daily Veget.                                   N/A
#
#   studentprice guestprice pupilprice    menudate  \
# 0         5,60       5,60       5,60  2024-11-22
# 1         5,60       5,60       5,60  2024-11-21
# 2         5,20       5,20       5,20  2024-11-21
#
#                                                 menu meats icons  \
# 0    Putengulasch Jäger Art, Spätzle, Bunte Karotten    {}    {}
# 1  Hähnchenbrustfilet Natur Gebraten [g], Käsesah...   {G}   {G}
# 2  Pasta Gemüse-ricotta Oder, Pasta Tomatensahnesoße    {}    {}
#
#   filtersinclude          allergens additives   co2  \
# 0             {}  {Ei,ML,Gl-a,Gl-e}        {}  None
# 1             {}    {Ei,So,ML,Gl-a}       {1}  None
# 2             {}            {Se,ML}        {}  None
#
#                          image_filename
# 0                                   N/A
# 1  34a051ac5e6ab1ac53b15aa0bab9df19.png
# 2  c6864080af19edb349a1ad3c3a2e0441.png
# Database connection closed.
